# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#test_df = pd.read_csv("test.csv")
train_df = pd.read_csv(
    'train.csv',
    on_bad_lines='skip',      # Skip malformed lines (like row 42805)
    encoding='utf-8',
    engine='python'           # More forgiving than default 'c' engine
)

# %%
test_df = pd.read_csv(
    "test.csv",
    on_bad_lines='skip',   # skips malformed lines
    encoding='utf-8',      # try utf-8 first
    engine='python'        # more forgiving parser
)

# %%
test_df.head()
# Out:
#    sample_id                                    catalog_content  \
# 0     100179  Item Name: Rani 14-Spice Eshamaya's Mango Chut...
# 1     245611  Item Name: Natural MILK TEA Flavoring extract ...
# 2     146263  Item Name: Honey Filled Hard Candy - Bulk Pack...
# 3      95658  Item Name: Vlasic Snack'mm's Kosher Dill 16 Oz...
# 4      36806  Item Name: McCormick Culinary Vanilla Extract,...
#
#                                           image_link
# 0  https://m.media-amazon.com/images/I/71hoAn78AW...
# 1  https://m.media-amazon.com/images/I/61ex8NHCIj...
# 2  https://m.media-amazon.com/images/I/61KCM61J8e...
# 3  https://m.media-amazon.com/images/I/51Ex6uOH7y...
# 4  https://m.media-amazon.com/images/I/71QYlrOMoS...

# %%
train_df.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
print(f"Test Shape:{test_df.shape}")
print(f"Train Shape:{train_df.shape}")
# Out:
# Test Shape:(75000, 3)
# Train Shape:(75000, 4)

# %%
print(f"Missing Values:{test_df.isnull().sum}")
print(f"Missing Values:{train_df.isnull().sum}")
# Out:
# Missing Values:<bound method DataFrame.sum of        sample_id  catalog_content  image_link
# 0          False            False       False
# 1          False            False       False
# 2          False            False       False
# 3          False            False       False
# 4          False            False       False
# ...          ...              ...         ...
# 74995      False            False       False
# 74996      False            False       False
# 74997      False            False       False
# 74998      False            False       False
# 74999      False            False       False
#
# [75000 rows x 3 columns]>
# Missing Values:<bound method DataFrame.sum of        sample_id  catalog_content  image_link  price
# 0          False            False       False  False
# 1          False            False       False  False
# 2          False            False       False  False
# 3          False            False       False  False
# 4          False            False       False  False
# ...          ...              ...         ...    ...
# 74995      False            False       False  False
# 74996      False            False       False  False
# 74997      False            False       False  False
# 74998      False            False       False  False
# 74999      False            False       False  False
#
# [75000 rows x 4 columns]>

# %%
# Remove negative or zero prices
train_df = train_df[train_df['price'] > 0]

# Optional: Remove extreme outliers (e.g., price > $10,000 if unrealistic)
train_df = train_df[train_df['price'] < 10000]

# %%
train_df['catalog_content'] = train_df['catalog_content'].fillna('unknown')
test_df['catalog_content'] = test_df['catalog_content'].fillna('unknown')

# %%
print(train_df['catalog_content'] == train_df['catalog_content'].fillna('unknown'))
print(test_df['catalog_content'] == test_df['catalog_content'].fillna('unknown'))
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 74995    True
# 74996    True
# 74997    True
# 74998    True
# 74999    True
# Name: catalog_content, Length: 75000, dtype: bool
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 74995    True
# 74996    True
# 74997    True
# 74998    True
# 74999    True
# Name: catalog_content, Length: 75000, dtype: bool

# %%
import re

def clean_text(text):
    text = str(text).lower()                     # lowercase
    text = re.sub(r'[^\w\s]', ' ', text)         # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()     # remove extra spaces
    return text

train_df['clean_text'] = train_df['catalog_content'].apply(clean_text)
test_df['clean_text'] = test_df['catalog_content'].apply(clean_text)

# %% [markdown]
# Handelling Images

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy as np

def load_image(url, size=(224, 224)):
    try:
        response = requests.get(url, timeout=10)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img = img.resize(size)
        return np.array(img) / 255.0  # normalize to [0,1]
    except:
        # Return a blank image if download fails
        return np.zeros((*size, 3))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Use your cleaned text column
tfidf = TfidfVectorizer(
    max_features=10000,     # limit to top 10k words
    stop_words='english',   # remove common words like "the", "and"
    ngram_range=(1, 2)      # use single words + pairs ("iphone case")
)

X_train_text = tfidf.fit_transform(train_df['clean_text'])
X_test_text = tfidf.transform(test_df['clean_text'])

y_train = train_df['price'].values

# %%
import torch
import torchvision.models as models
from torchvision import transforms
from PIL import Image
import numpy as np
import os

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pretrained MobileNetV2
mobilenet = models.mobilenet_v2(pretrained=True)
mobilenet = torch.nn.Sequential(*list(mobilenet.children())[:-1])  # Remove classifier layer
mobilenet.eval().to(device)

# Define image transform
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def get_mobilenet_features(img_path):
    try:
        img = Image.open(img_path).convert('RGB')
        img_t = transform(img).unsqueeze(0).to(device)  # Add batch dim
        with torch.no_grad():
            features = mobilenet(img_t)
        return features.cpu().numpy().flatten()  # Shape: (1280,)
    except Exception as e:
        print(f"Error loading {img_path}: {e}")
        return np.zeros(1280)  # MobileNetV2 last layer before classifier has 1280 features
# Out:
# c:\Users\P.V.H.Shanmukha\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\P.V.H.Shanmukha\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Clean text (if not already done)
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['clean_text'] = train_df['catalog_content'].fillna('unknown').apply(clean_text)
test_df['clean_text'] = test_df['catalog_content'].fillna('unknown').apply(clean_text)

# TF-IDF for text
tfidf = TfidfVectorizer(max_features=5000, stop_words='english', ngram_range=(1,2))
X_train_text = tfidf.fit_transform(train_df['clean_text'])
X_test_text = tfidf.transform(test_df['clean_text'])

# %%
import os
import requests
from PIL import Image
from io import BytesIO

def download_image(url, save_path):
    try:
        response = requests.get(url, timeout=10)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img.save(save_path)
        return True
    except Exception as e:
        print(f"❌ Failed to download {url} → {e}")
        # Save blank image so feature extractor doesn't crash
        blank = Image.new('RGB', (224, 224), (0, 0, 0))
        blank.save(save_path)
        return False

# Create folders
os.makedirs('train_images', exist_ok=True)
os.makedirs('test_images', exist_ok=True)

# Download train images
for idx, row in train_df.iterrows():
    img_path = f"train_images/{row['sample_id']}.jpg"
    if not os.path.exists(img_path):  # only download if not already there
        download_image(row['image_link'], img_path)
    if idx % 100 == 0:
        print(f"✅ Downloaded {idx} train images...")

# Download test images
for idx, row in test_df.iterrows():
    img_path = f"test_images/{row['sample_id']}.jpg"
    if not os.path.exists(img_path):
        download_image(row['image_link'], img_path)
    if idx % 100 == 0:
        print(f"✅ Downloaded {idx} test images...")
# Out:
# ✅ Downloaded 0 train images...
# ✅ Downloaded 100 train images...
# ✅ Downloaded 200 train images...
# ✅ Downloaded 300 train images...
# ✅ Downloaded 400 train images...
# ✅ Downloaded 500 train images...
# ✅ Downloaded 600 train images...
# ✅ Downloaded 700 train images...
# ✅ Downloaded 800 train images...
# ✅ Downloaded 900 train images...
# ✅ Downloaded 1000 train images...
# ✅ Downloaded 1100 train images...
# ✅ Downloaded 1200 train images...
# ✅ Downloaded 1300 train images...
# ✅ Downloaded 1400 train images...
# ✅ Downloaded 1500 train images...
# ✅ Downloaded 1600 train images...
# ✅ Downloaded 1700 train images...
# ✅ Downloaded 1800 train images...
# ✅ Downloaded 1900 train images...
# ✅ Downloaded 2000 train images...
# ✅ Downloaded 2100 train images...
# ✅ Downloaded 2200 train images...
# ✅ Downloaded 2300 train images...
# ✅ Downloaded 2400 train images...
# ✅ Downloaded 2500 train images...
# ✅ Downloaded 2600 train images...
# ✅ Downloaded 2700 train images...
# ✅ Downloaded 2800 train images...
# ✅ Downloaded 2900 train images...
# ✅ Downloaded 3000 train images...
# ✅ Downloaded 3100 train images...
# ✅ Downloaded 3200 train images...
# ✅ Downloaded 3300 train images...
# ✅ Downloaded 3400 train images...
# ✅ Downloaded 3500 train images...
# ✅ Downloaded 3600 train images...
# ✅ Downloaded 3700 train images...
# ✅ Downloaded 3800 train images...
# ✅ Downloaded 3900 train images...
# ✅ Downloaded 4000 train images...
# ✅ Downloaded 4100 train images...
# ✅ Downloaded 4200 train images...
# ✅ Downloaded 4300 train images...
# ✅ Downloaded 4400 train images...
# ✅ Downloaded 4500 train images...
# ✅ Downloaded 4600 train images...
# ✅ Downloaded 4700 train images...
# ✅ Downloaded 4800 train images...
# ✅ Downloaded 4900 train images...
# ✅ Downloaded 5000 train images...
# ✅ Downloaded 5100 train images...
# ✅ Downloaded 5200 train images...
# ✅ Downloaded 5300 train images...
# ✅ Downloaded 5400 train images...
# ✅ Downloaded 5500 train images...
# ✅ Downloaded 5600 train images...
# ✅ Downloaded 5700 train images...
# ✅ Downloaded 5800 train images...
# ✅ Downloaded 5900 train images...
# ✅ Downloaded 6000 train images...
# ✅ Downloaded 6100 train images...
# ✅ Downloaded 6200 train images...
# ✅ Downloaded 6300 train images...
# ✅ Downloaded 6400 train images...
# ✅ Downloaded 6500 train images...
# ✅ Downloaded 6600 train images...
# ✅ Downloaded 6700 train images...
# ✅ Downloaded 6800 train images...
# ✅ Downloaded 6900 train images...
# ✅ Downloaded 7000 train images...
# ✅ Downloaded 7100 train images...
# ✅ Downloaded 7200 train images...
# ✅ Downloaded 7300 train images...
# ✅ Downloaded 7400 train images...
# ✅ Downloaded 7500 train images...
# ✅ Downloaded 7600 train images...
# ✅ Downloaded 7700 train images...
# ✅ Downloaded 7800 train images...
# ✅ Downloaded 7900 train images...
# ✅ Downloaded 8000 train images...
# ✅ Downloaded 8100 train images...
# ✅ Downloaded 8200 train images...
# ✅ Downloaded 8300 train images...
# ✅ Downloaded 8400 train images...
# ✅ Downloaded 8500 train images...
# ✅ Downloaded 8600 train images...
# ✅ Downloaded 8700 train images...
# ✅ Downloaded 8800 train images...
# ✅ Downloaded 8900 train images...
# ✅ Downloaded 9000 train images...
# ✅ Downloaded 9100 train images...
# ✅ Downloaded 9200 train images...
# ✅ Downloaded 9300 train images...
# ✅ Downloaded 9400 train images...
# ✅ Downloaded 9500 train images...
# ✅ Downloaded 9600 train images...
# ✅ Downloaded 9700 train images...
# ✅ Downloaded 9800 train images...
# ✅ Downloaded 9900 train images...
# ✅ Downloaded 10000 train images...
# ✅ Downloaded 10100 train images...
# ✅ Downloaded 10200 train images...
# ✅ Downloaded 10300 train images...
# ✅ Downloaded 10400 train images...
# ✅ Downloaded 10500 train images...
# ✅ Downloaded 10600 train images...
# ✅ Downloaded 10700 train images...
# ✅ Downloaded 10800 train images...
# ✅ Downloaded 10900 train images...
# ✅ Downloaded 11000 train images...
# ✅ Downloaded 11100 train images...
# ✅ Downloaded 11200 train images...
# ✅ Downloaded 11300 train images...
# ✅ Downloaded 11400 train images...
# ✅ Downloaded 11500 train images...
# ✅ Downloaded 11600 train images...
# ✅ Downloaded 11700 train images...
# ✅ Downloaded 11800 train images...
# ✅ Downloaded 11900 train images...
# ✅ Downloaded 12000 train images...
# ✅ Downloaded 12100 train images...
# ✅ Downloaded 12200 train images...
# ✅ Downloaded 12300 train images...
# ✅ Downloaded 12400 train images...
# ✅ Downloaded 12500 train images...
# ✅ Downloaded 12600 train images...
# ✅ Downloaded 12700 train images...
# ✅ Downloaded 12800 train images...
# ✅ Downloaded 12900 train images...
# ✅ Downloaded 13000 train images...
# ✅ Downloaded 13100 train images...
# ✅ Downloaded 13200 train images...
# ✅ Downloaded 13300 train images...
# ✅ Downloaded 13400 train images...
# ✅ Downloaded 13500 train images...
# ✅ Downloaded 13600 train images...
# ✅ Downloaded 13700 train images...
# ✅ Downloaded 13800 train images...
# ✅ Downloaded 13900 train images...
# ✅ Downloaded 14000 train images...
# ✅ Downloaded 14100 train images...
# ✅ Downloaded 14200 train images...
# ✅ Downloaded 14300 train images...
# ✅ Downloaded 14400 train images...
# ✅ Downloaded 14500 train images...
# ✅ Downloaded 14600 train images...
# ✅ Downloaded 14700 train images...
# ✅ Downloaded 14800 train images...
# ✅ Downloaded 14900 train images...
# ✅ Downloaded 15000 train images...
# ✅ Downloaded 15100 train images...
# ✅ Downloaded 15200 train images...
# ✅ Downloaded 15300 train images...
# ✅ Downloaded 15400 train images...
# ✅ Downloaded 15500 train images...
# ✅ Downloaded 15600 train images...
# ✅ Downloaded 15700 train images...
# ✅ Downloaded 15800 train images...
# ✅ Downloaded 15900 train images...
# ✅ Downloaded 16000 train images...
# ✅ Downloaded 16100 train images...
# ✅ Downloaded 16200 train images...
# ✅ Downloaded 16300 train images...
# ✅ Downloaded 16400 train images...
# ✅ Downloaded 16500 train images...
# ✅ Downloaded 16600 train images...
# ✅ Downloaded 16700 train images...
# ✅ Downloaded 16800 train images...
# ✅ Downloaded 16900 train images...
# ✅ Downloaded 17000 train images...
# ✅ Downloaded 17100 train images...
# ✅ Downloaded 17200 train images...
# ✅ Downloaded 17300 train images...
# ✅ Downloaded 17400 train images...
# ✅ Downloaded 17500 train images...
# ✅ Downloaded 17600 train images...
# ✅ Downloaded 17700 train images...
# ✅ Downloaded 17800 train images...
# ✅ Downloaded 17900 train images...
# ✅ Downloaded 18000 train images...
# ✅ Downloaded 18100 train images...
# ✅ Downloaded 18200 train images...
# ✅ Downloaded 18300 train images...
# ✅ Downloaded 18400 train images...
# ✅ Downloaded 18500 train images...
# ✅ Downloaded 18600 train images...
# ✅ Downloaded 18700 train images...
# ✅ Downloaded 18800 train images...
# ✅ Downloaded 18900 train images...
# ✅ Downloaded 19000 train images...
# ✅ Downloaded 19100 train images...
# ✅ Downloaded 19200 train images...
# ✅ Downloaded 19300 train images...
# ✅ Downloaded 19400 train images...
# ✅ Downloaded 19500 train images...
# ✅ Downloaded 19600 train images...
# ✅ Downloaded 19700 train images...
# ✅ Downloaded 19800 train images...
# ✅ Downloaded 19900 train images...
# ✅ Downloaded 20000 train images...
# ✅ Downloaded 20100 train images...
# ✅ Downloaded 20200 train images...
# ✅ Downloaded 20300 train images...
# ✅ Downloaded 20400 train images...
# ✅ Downloaded 20500 train images...
# ✅ Downloaded 20600 train images...
# ✅ Downloaded 20700 train images...
# ✅ Downloaded 20800 train images...
# ✅ Downloaded 20900 train images...
# ✅ Downloaded 21000 train images...
# ✅ Downloaded 21100 train images...
# ✅ Downloaded 21200 train images...
# ✅ Downloaded 21300 train images...
# ✅ Downloaded 21400 train images...
# ✅ Downloaded 21500 train images...
# ✅ Downloaded 21600 train images...
# ✅ Downloaded 21700 train images...
# ✅ Downloaded 21800 train images...
# ✅ Downloaded 21900 train images...
# ✅ Downloaded 22000 train images...
# ✅ Downloaded 22100 train images...
# ✅ Downloaded 22200 train images...
# ✅ Downloaded 22300 train images...
# ✅ Downloaded 22400 train images...
# ✅ Downloaded 22500 train images...
# ✅ Downloaded 22600 train images...
# ✅ Downloaded 22700 train images...
# ✅ Downloaded 22800 train images...
# ✅ Downloaded 22900 train images...
# ✅ Downloaded 23000 train images...
# ✅ Downloaded 23100 train images...
# ✅ Downloaded 23200 train images...
# ✅ Downloaded 23300 train images...
# ✅ Downloaded 23400 train images...
# ✅ Downloaded 23500 train images...
# ✅ Downloaded 23600 train images...
# ✅ Downloaded 23700 train images...
# ✅ Downloaded 23800 train images...
# ✅ Downloaded 23900 train images...
# ✅ Downloaded 24000 train images...
# ✅ Downloaded 24100 train images...
# ✅ Downloaded 24200 train images...
# ✅ Downloaded 24300 train images...
# ✅ Downloaded 24400 train images...
# ✅ Downloaded 24500 train images...
# ✅ Downloaded 24600 train images...
# ✅ Downloaded 24700 train images...
# ✅ Downloaded 24800 train images...
# ✅ Downloaded 24900 train images...
# ✅ Downloaded 25000 train images...
# ✅ Downloaded 25100 train images...
# ✅ Downloaded 25200 train images...
# ✅ Downloaded 25300 train images...
# ✅ Downloaded 25400 train images...
# ✅ Downloaded 25500 train images...
# ✅ Downloaded 25600 train images...
# ✅ Downloaded 25700 train images...
# ✅ Downloaded 25800 train images...
# ✅ Downloaded 25900 train images...
# ✅ Downloaded 26000 train images...
# ✅ Downloaded 26100 train images...
# ✅ Downloaded 26200 train images...
# ✅ Downloaded 26300 train images...
# ✅ Downloaded 26400 train images...
# ✅ Downloaded 26500 train images...
# ✅ Downloaded 26600 train images...
# ✅ Downloaded 26700 train images...
# ✅ Downloaded 26800 train images...
# ✅ Downloaded 26900 train images...
# ✅ Downloaded 27000 train images...
# ✅ Downloaded 27100 train images...
# ✅ Downloaded 27200 train images...
# ✅ Downloaded 27300 train images...
# ✅ Downloaded 27400 train images...
# ✅ Downloaded 27500 train images...
# ✅ Downloaded 27600 train images...
# ✅ Downloaded 27700 train images...
# ✅ Downloaded 27800 train images...
# ✅ Downloaded 27900 train images...
# ✅ Downloaded 28000 train images...
# ✅ Downloaded 28100 train images...
# ✅ Downloaded 28200 train images...
# ✅ Downloaded 28300 train images...
# ✅ Downloaded 28400 train images...
# ✅ Downloaded 28500 train images...
# ✅ Downloaded 28600 train images...
# ✅ Downloaded 28700 train images...
# ✅ Downloaded 28800 train images...
# ✅ Downloaded 28900 train images...
# ✅ Downloaded 29000 train images...
# ✅ Downloaded 29100 train images...
# ✅ Downloaded 29200 train images...
# ✅ Downloaded 29300 train images...
# ✅ Downloaded 29400 train images...
# ✅ Downloaded 29500 train images...
# ✅ Downloaded 29600 train images...
# ✅ Downloaded 29700 train images...
# ✅ Downloaded 29800 train images...
# ✅ Downloaded 29900 train images...
# ✅ Downloaded 30000 train images...
# ✅ Downloaded 30100 train images...
# ✅ Downloaded 30200 train images...
# ✅ Downloaded 30300 train images...
# ✅ Downloaded 30400 train images...
# ✅ Downloaded 30500 train images...
# ✅ Downloaded 30600 train images...
# ✅ Downloaded 30700 train images...
# ✅ Downloaded 30800 train images...
# ✅ Downloaded 30900 train images...
# ✅ Downloaded 31000 train images...
# ✅ Downloaded 31100 train images...
# ✅ Downloaded 31200 train images...
# ✅ Downloaded 31300 train images...
# ✅ Downloaded 31400 train images...
# ✅ Downloaded 31500 train images...
# ✅ Downloaded 31600 train images...
# ✅ Downloaded 31700 train images...
# ✅ Downloaded 31800 train images...
# ✅ Downloaded 31900 train images...
# ✅ Downloaded 32000 train images...
# ✅ Downloaded 32100 train images...
# ✅ Downloaded 32200 train images...
# ✅ Downloaded 32300 train images...
# ✅ Downloaded 32400 train images...
# ✅ Downloaded 32500 train images...
# ✅ Downloaded 32600 train images...
# ✅ Downloaded 32700 train images...
# ✅ Downloaded 32800 train images...
# ✅ Downloaded 32900 train images...
# ✅ Downloaded 33000 train images...
# ✅ Downloaded 33100 train images...
# ✅ Downloaded 33200 train images...
# ✅ Downloaded 33300 train images...
# ✅ Downloaded 33400 train images...
# ✅ Downloaded 33500 train images...
# ✅ Downloaded 33600 train images...
# ✅ Downloaded 33700 train images...
# ✅ Downloaded 33800 train images...
# ✅ Downloaded 33900 train images...
# ✅ Downloaded 34000 train images...
# ✅ Downloaded 34100 train images...
# ✅ Downloaded 34200 train images...
# ✅ Downloaded 34300 train images...
# ✅ Downloaded 34400 train images...
# ✅ Downloaded 34500 train images...
# ✅ Downloaded 34600 train images...
# ✅ Downloaded 34700 train images...
# ✅ Downloaded 34800 train images...
# ✅ Downloaded 34900 train images...
# ✅ Downloaded 35000 train images...
# ✅ Downloaded 35100 train images...
# ✅ Downloaded 35200 train images...
# ✅ Downloaded 35300 train images...
# ✅ Downloaded 35400 train images...
# ✅ Downloaded 35500 train images...
# ✅ Downloaded 35600 train images...
# ✅ Downloaded 35700 train images...
# ✅ Downloaded 35800 train images...
# ✅ Downloaded 35900 train images...
# ✅ Downloaded 36000 train images...
# ✅ Downloaded 36100 train images...
# ✅ Downloaded 36200 train images...
# ✅ Downloaded 36300 train images...
# ✅ Downloaded 36400 train images...
# ✅ Downloaded 36500 train images...
# ✅ Downloaded 36600 train images...
# ✅ Downloaded 36700 train images...
# ✅ Downloaded 36800 train images...
# ✅ Downloaded 36900 train images...
# ✅ Downloaded 37000 train images...
# ✅ Downloaded 37100 train images...
# ✅ Downloaded 37200 train images...
# ✅ Downloaded 37300 train images...
# ✅ Downloaded 37400 train images...
# ✅ Downloaded 37500 train images...
# ✅ Downloaded 37600 train images...
# ✅ Downloaded 37700 train images...
# ✅ Downloaded 37800 train images...
# ✅ Downloaded 37900 train images...
# ✅ Downloaded 38000 train images...
# ✅ Downloaded 38100 train images...
# ✅ Downloaded 38200 train images...
# ✅ Downloaded 38300 train images...
# ✅ Downloaded 38400 train images...
# ✅ Downloaded 38500 train images...
# ✅ Downloaded 38600 train images...
# ✅ Downloaded 38700 train images...
# ✅ Downloaded 38800 train images...
# ✅ Downloaded 38900 train images...
# ❌ Failed to download https://m.media-amazon.com/images/I/51mjZYDYjyL.jpg → cannot identify image file <_io.BytesIO object at 0x00000235C25A9030>
# ✅ Downloaded 39000 train images...
# ✅ Downloaded 39100 train images...
# ✅ Downloaded 39200 train images...
# ✅ Downloaded 39300 train images...
# ✅ Downloaded 39400 train images...
# ✅ Downloaded 39500 train images...
# ✅ Downloaded 39600 train images...
# ✅ Downloaded 39700 train images...
# ✅ Downloaded 39800 train images...
# ✅ Downloaded 39900 train images...
# ✅ Downloaded 40000 train images...
# ✅ Downloaded 40100 train images...
# ✅ Downloaded 40200 train images...
# ✅ Downloaded 40300 train images...
# ✅ Downloaded 40400 train images...
# ✅ Downloaded 40500 train images...
# ✅ Downloaded 40600 train images...
# ✅ Downloaded 40700 train images...
# ✅ Downloaded 40800 train images...
# ✅ Downloaded 40900 train images...
# ✅ Downloaded 41000 train images...
# ✅ Downloaded 41100 train images...
# ✅ Downloaded 41200 train images...
# ✅ Downloaded 41300 train images...
# ✅ Downloaded 41400 train images...
# ✅ Downloaded 41500 train images...
# ✅ Downloaded 41600 train images...
# ✅ Downloaded 41700 train images...
# ✅ Downloaded 41800 train images...
# ✅ Downloaded 41900 train images...
# ✅ Downloaded 42000 train images...
# ✅ Downloaded 42100 train images...
# ✅ Downloaded 42200 train images...
# ✅ Downloaded 42300 train images...
# ✅ Downloaded 42400 train images...
# ✅ Downloaded 42500 train images...
# ✅ Downloaded 42600 train images...
# ✅ Downloaded 42700 train images...
# ✅ Downloaded 42800 train images...
# ✅ Downloaded 42900 train images...
# ✅ Downloaded 43000 train images...
# ✅ Downloaded 43100 train images...
# ✅ Downloaded 43200 train images...
# ✅ Downloaded 43300 train images...
# ✅ Downloaded 43400 train images...
# ✅ Downloaded 43500 train images...
# ✅ Downloaded 43600 train images...
# ✅ Downloaded 43700 train images...
# ✅ Downloaded 43800 train images...
# ✅ Downloaded 43900 train images...
# ✅ Downloaded 44000 train images...
# ✅ Downloaded 44100 train images...
# ✅ Downloaded 44200 train images...
# ✅ Downloaded 44300 train images...
# ✅ Downloaded 44400 train images...
# ✅ Downloaded 44500 train images...
# ✅ Downloaded 44600 train images...
# ✅ Downloaded 44700 train images...
# ✅ Downloaded 44800 train images...
# ✅ Downloaded 44900 train images...
# ✅ Downloaded 45000 train images...
# ✅ Downloaded 45100 train images...
# ✅ Downloaded 45200 train images...
# ✅ Downloaded 45300 train images...
# ✅ Downloaded 45400 train images...
# ✅ Downloaded 45500 train images...
# ✅ Downloaded 45600 train images...
# ✅ Downloaded 45700 train images...
# ✅ Downloaded 45800 train images...
# ✅ Downloaded 45900 train images...
# ✅ Downloaded 46000 train images...
# ✅ Downloaded 46100 train images...
# ✅ Downloaded 46200 train images...
# ✅ Downloaded 46300 train images...
# ✅ Downloaded 46400 train images...
# ✅ Downloaded 46500 train images...
# ✅ Downloaded 46600 train images...
# ✅ Downloaded 46700 train images...
# ✅ Downloaded 46800 train images...
# ✅ Downloaded 46900 train images...
# ✅ Downloaded 47000 train images...
# ✅ Downloaded 47100 train images...
# ✅ Downloaded 47200 train images...
# ✅ Downloaded 47300 train images...
# ✅ Downloaded 47400 train images...
# ✅ Downloaded 47500 train images...
# ✅ Downloaded 47600 train images...
# ✅ Downloaded 47700 train images...
# ✅ Downloaded 47800 train images...
# ✅ Downloaded 47900 train images...
# ✅ Downloaded 48000 train images...
# ✅ Downloaded 48100 train images...
# ✅ Downloaded 48200 train images...
# ✅ Downloaded 48300 train images...
# ✅ Downloaded 48400 train images...
# ✅ Downloaded 48500 train images...
# ✅ Downloaded 48600 train images...
# ✅ Downloaded 48700 train images...
# ✅ Downloaded 48800 train images...
# ✅ Downloaded 48900 train images...
# ✅ Downloaded 49000 train images...
# ✅ Downloaded 49100 train images...
# ✅ Downloaded 49200 train images...
# ✅ Downloaded 49300 train images...
# ✅ Downloaded 49400 train images...
# ✅ Downloaded 49500 train images...
# ✅ Downloaded 49600 train images...
# ✅ Downloaded 49700 train images...
# ✅ Downloaded 49800 train images...
# ✅ Downloaded 49900 train images...
# ✅ Downloaded 50000 train images...
# ✅ Downloaded 50100 train images...
# ✅ Downloaded 50200 train images...
# ✅ Downloaded 50300 train images...
# ✅ Downloaded 50400 train images...
# ✅ Downloaded 50500 train images...
# ✅ Downloaded 50600 train images...
# ✅ Downloaded 50700 train images...
# ✅ Downloaded 50800 train images...
# ✅ Downloaded 50900 train images...
# ✅ Downloaded 51000 train images...
# ✅ Downloaded 51100 train images...
# ✅ Downloaded 51200 train images...
# ✅ Downloaded 51300 train images...
# ✅ Downloaded 51400 train images...
# ✅ Downloaded 51500 train images...
# ✅ Downloaded 51600 train images...
# ✅ Downloaded 51700 train images...
# ✅ Downloaded 51800 train images...
# ✅ Downloaded 51900 train images...
# ✅ Downloaded 52000 train images...
# ✅ Downloaded 52100 train images...
# ✅ Downloaded 52200 train images...
# ✅ Downloaded 52300 train images...
# ✅ Downloaded 52400 train images...
# ✅ Downloaded 52500 train images...
# ✅ Downloaded 52600 train images...
# ✅ Downloaded 52700 train images...
# ✅ Downloaded 52800 train images...
# ✅ Downloaded 52900 train images...
# ✅ Downloaded 53000 train images...
# ✅ Downloaded 53100 train images...
# ✅ Downloaded 53200 train images...
# ✅ Downloaded 53300 train images...
# ✅ Downloaded 53400 train images...
# ✅ Downloaded 53500 train images...
# ✅ Downloaded 53600 train images...
# ✅ Downloaded 53700 train images...
# ✅ Downloaded 53800 train images...
# ✅ Downloaded 53900 train images...
# ✅ Downloaded 54000 train images...
# ✅ Downloaded 54100 train images...
# ✅ Downloaded 54200 train images...
# ✅ Downloaded 54300 train images...
# ✅ Downloaded 54400 train images...
# ✅ Downloaded 54500 train images...
# ✅ Downloaded 54600 train images...
# ✅ Downloaded 54700 train images...
# ✅ Downloaded 54800 train images...
# ✅ Downloaded 54900 train images...
# ✅ Downloaded 55000 train images...
# ✅ Downloaded 55100 train images...
# ✅ Downloaded 55200 train images...
# ✅ Downloaded 55300 train images...
# ✅ Downloaded 55400 train images...
# ✅ Downloaded 55500 train images...
# ✅ Downloaded 55600 train images...
# ✅ Downloaded 55700 train images...
# ✅ Downloaded 55800 train images...
# ✅ Downloaded 55900 train images...
# ✅ Downloaded 56000 train images...
# ✅ Downloaded 56100 train images...
# ✅ Downloaded 56200 train images...
# ✅ Downloaded 56300 train images...
# ✅ Downloaded 56400 train images...
# ✅ Downloaded 56500 train images...
# ✅ Downloaded 56600 train images...
# ✅ Downloaded 56700 train images...
# ✅ Downloaded 56800 train images...
# ✅ Downloaded 56900 train images...
# ✅ Downloaded 57000 train images...
# ✅ Downloaded 57100 train images...
# ✅ Downloaded 57200 train images...
# ✅ Downloaded 57300 train images...
# ✅ Downloaded 57400 train images...
# ✅ Downloaded 57500 train images...
# ✅ Downloaded 57600 train images...
# ✅ Downloaded 57700 train images...
# ✅ Downloaded 57800 train images...
# ✅ Downloaded 57900 train images...
# ✅ Downloaded 58000 train images...
# ✅ Downloaded 58100 train images...
# ✅ Downloaded 58200 train images...
# ✅ Downloaded 58300 train images...
# ✅ Downloaded 58400 train images...
# ✅ Downloaded 58500 train images...
# ✅ Downloaded 58600 train images...
# ✅ Downloaded 58700 train images...
# ✅ Downloaded 58800 train images...
# ✅ Downloaded 58900 train images...
# ✅ Downloaded 59000 train images...
# ✅ Downloaded 59100 train images...
# ✅ Downloaded 59200 train images...
# ✅ Downloaded 59300 train images...
# ✅ Downloaded 59400 train images...
# ✅ Downloaded 59500 train images...
# ✅ Downloaded 59600 train images...
# ✅ Downloaded 59700 train images...
# ✅ Downloaded 59800 train images...
# ✅ Downloaded 59900 train images...
# ✅ Downloaded 60000 train images...
# ✅ Downloaded 60100 train images...
# ✅ Downloaded 60200 train images...
# ✅ Downloaded 60300 train images...
# ✅ Downloaded 60400 train images...
# ✅ Downloaded 60500 train images...
# ✅ Downloaded 60600 train images...
# ✅ Downloaded 60700 train images...
# ✅ Downloaded 60800 train images...
# ✅ Downloaded 60900 train images...
# ✅ Downloaded 61000 train images...
# ✅ Downloaded 61100 train images...
# ✅ Downloaded 61200 train images...
# ✅ Downloaded 61300 train images...
# ✅ Downloaded 61400 train images...
# ✅ Downloaded 61500 train images...
# ✅ Downloaded 61600 train images...
# ✅ Downloaded 61700 train images...
# ✅ Downloaded 61800 train images...
# ✅ Downloaded 61900 train images...
# ✅ Downloaded 62000 train images...
# ✅ Downloaded 62100 train images...
# ✅ Downloaded 62200 train images...
# ✅ Downloaded 62300 train images...
# ✅ Downloaded 62400 train images...
# ✅ Downloaded 62500 train images...
# ✅ Downloaded 62600 train images...
# ✅ Downloaded 62700 train images...
# ✅ Downloaded 62800 train images...
# ✅ Downloaded 62900 train images...
# ✅ Downloaded 63000 train images...
# ✅ Downloaded 63100 train images...
# ✅ Downloaded 63200 train images...
# ✅ Downloaded 63300 train images...
# ✅ Downloaded 63400 train images...
# ✅ Downloaded 63500 train images...
# ✅ Downloaded 63600 train images...
# ✅ Downloaded 63700 train images...
# ✅ Downloaded 63800 train images...
# ✅ Downloaded 63900 train images...
# ✅ Downloaded 64000 train images...
# ✅ Downloaded 64100 train images...
# ✅ Downloaded 64200 train images...
# ✅ Downloaded 64300 train images...
# ✅ Downloaded 64400 train images...
# ✅ Downloaded 64500 train images...
# ✅ Downloaded 64600 train images...
# ✅ Downloaded 64700 train images...
# ✅ Downloaded 64800 train images...
# ✅ Downloaded 64900 train images...
# ✅ Downloaded 65000 train images...
# ✅ Downloaded 65100 train images...
# ✅ Downloaded 65200 train images...
# ✅ Downloaded 65300 train images...
# ✅ Downloaded 65400 train images...
# ✅ Downloaded 65500 train images...
# ✅ Downloaded 65600 train images...
# ✅ Downloaded 65700 train images...
# ✅ Downloaded 65800 train images...
# ✅ Downloaded 65900 train images...
# ✅ Downloaded 66000 train images...
# ✅ Downloaded 66100 train images...
# ✅ Downloaded 66200 train images...
# ✅ Downloaded 66300 train images...
# ✅ Downloaded 66400 train images...
# ✅ Downloaded 66500 train images...
# ✅ Downloaded 66600 train images...
# ✅ Downloaded 66700 train images...
# ✅ Downloaded 66800 train images...
# ✅ Downloaded 66900 train images...
# ✅ Downloaded 67000 train images...
# ✅ Downloaded 67100 train images...
# ✅ Downloaded 67200 train images...
# ✅ Downloaded 67300 train images...
# ✅ Downloaded 67400 train images...
# ✅ Downloaded 67500 train images...
# ✅ Downloaded 67600 train images...
# ✅ Downloaded 67700 train images...
# ✅ Downloaded 67800 train images...
# ✅ Downloaded 67900 train images...
# ✅ Downloaded 68000 train images...
# ✅ Downloaded 68100 train images...
# ✅ Downloaded 68200 train images...
# ✅ Downloaded 68300 train images...
# ✅ Downloaded 68400 train images...
# ✅ Downloaded 68500 train images...
# ✅ Downloaded 68600 train images...
# ✅ Downloaded 68700 train images...
# ✅ Downloaded 68800 train images...
# ✅ Downloaded 68900 train images...
# ✅ Downloaded 69000 train images...
# ✅ Downloaded 69100 train images...
# ✅ Downloaded 69200 train images...
# ✅ Downloaded 69300 train images...
# ✅ Downloaded 69400 train images...
# ✅ Downloaded 69500 train images...
# ✅ Downloaded 69600 train images...
# ✅ Downloaded 69700 train images...
# ✅ Downloaded 69800 train images...
# ✅ Downloaded 69900 train images...
# ✅ Downloaded 70000 train images...
# ✅ Downloaded 70100 train images...
# ✅ Downloaded 70200 train images...
# ✅ Downloaded 70300 train images...
# ✅ Downloaded 70400 train images...
# ✅ Downloaded 70500 train images...
# ✅ Downloaded 70600 train images...
# ✅ Downloaded 70700 train images...
# ✅ Downloaded 70800 train images...
# ✅ Downloaded 70900 train images...
# ✅ Downloaded 71000 train images...
# ✅ Downloaded 71100 train images...
# ✅ Downloaded 71200 train images...
# ✅ Downloaded 71300 train images...
# ✅ Downloaded 71400 train images...
# ✅ Downloaded 71500 train images...
# ✅ Downloaded 71600 train images...
# ✅ Downloaded 71700 train images...
# ✅ Downloaded 71800 train images...
# ✅ Downloaded 71900 train images...
# ✅ Downloaded 72000 train images...
# ✅ Downloaded 72100 train images...
# ✅ Downloaded 72200 train images...
# ✅ Downloaded 72300 train images...
# ✅ Downloaded 72400 train images...
# ✅ Downloaded 72500 train images...
# ✅ Downloaded 72600 train images...
# ✅ Downloaded 72700 train images...
# ✅ Downloaded 72800 train images...
# ✅ Downloaded 72900 train images...
# ✅ Downloaded 73000 train images...
# ✅ Downloaded 73100 train images...
# ✅ Downloaded 73200 train images...
# ✅ Downloaded 73300 train images...
# ✅ Downloaded 73400 train images...
# ✅ Downloaded 73500 train images...
# ✅ Downloaded 73600 train images...
# ✅ Downloaded 73700 train images...
# ✅ Downloaded 73800 train images...
# ✅ Downloaded 73900 train images...
# ✅ Downloaded 74000 train images...
# ✅ Downloaded 74100 train images...
# ✅ Downloaded 74200 train images...
# ✅ Downloaded 74300 train images...
# ✅ Downloaded 74400 train images...
# ✅ Downloaded 74500 train images...
# ✅ Downloaded 74600 train images...
# ✅ Downloaded 74700 train images...
# ✅ Downloaded 74800 train images...
# ✅ Downloaded 74900 train images...
# ✅ Downloaded 0 test images...
# ✅ Downloaded 100 test images...
# ✅ Downloaded 200 test images...
# ✅ Downloaded 300 test images...
# ✅ Downloaded 400 test images...
# ✅ Downloaded 500 test images...
# ✅ Downloaded 600 test images...
# ✅ Downloaded 700 test images...
# ✅ Downloaded 800 test images...
# ✅ Downloaded 900 test images...
# ✅ Downloaded 1000 test images...
# ✅ Downloaded 1100 test images...
# ✅ Downloaded 1200 test images...
# ✅ Downloaded 1300 test images...
# ✅ Downloaded 1400 test images...
# ✅ Downloaded 1500 test images...
# ✅ Downloaded 1600 test images...
# ✅ Downloaded 1700 test images...
# ✅ Downloaded 1800 test images...
# ✅ Downloaded 1900 test images...
# ✅ Downloaded 2000 test images...
# ✅ Downloaded 2100 test images...
# ✅ Downloaded 2200 test images...
# ✅ Downloaded 2300 test images...
# ✅ Downloaded 2400 test images...
# ✅ Downloaded 2500 test images...
# ✅ Downloaded 2600 test images...
# ✅ Downloaded 2700 test images...
# ✅ Downloaded 2800 test images...
# ✅ Downloaded 2900 test images...
# ✅ Downloaded 3000 test images...
# ✅ Downloaded 3100 test images...
# ✅ Downloaded 3200 test images...
# ✅ Downloaded 3300 test images...
# ✅ Downloaded 3400 test images...
# ✅ Downloaded 3500 test images...
# ✅ Downloaded 3600 test images...
# ✅ Downloaded 3700 test images...
# ✅ Downloaded 3800 test images...
# ✅ Downloaded 3900 test images...
# ✅ Downloaded 4000 test images...
# ✅ Downloaded 4100 test images...
# ✅ Downloaded 4200 test images...
# ✅ Downloaded 4300 test images...
# ✅ Downloaded 4400 test images...
# ✅ Downloaded 4500 test images...
# ✅ Downloaded 4600 test images...
# ✅ Downloaded 4700 test images...
# ✅ Downloaded 4800 test images...
# ✅ Downloaded 4900 test images...
# ✅ Downloaded 5000 test images...
# ✅ Downloaded 5100 test images...
# ✅ Downloaded 5200 test images...
# ✅ Downloaded 5300 test images...
# ✅ Downloaded 5400 test images...
# ✅ Downloaded 5500 test images...
# ✅ Downloaded 5600 test images...
# ✅ Downloaded 5700 test images...
# ✅ Downloaded 5800 test images...
# ✅ Downloaded 5900 test images...
# ✅ Downloaded 6000 test images...
# ✅ Downloaded 6100 test images...
# ✅ Downloaded 6200 test images...
# ✅ Downloaded 6300 test images...
# ✅ Downloaded 6400 test images...
# ✅ Downloaded 6500 test images...
# ✅ Downloaded 6600 test images...
# ✅ Downloaded 6700 test images...
# ✅ Downloaded 6800 test images...
# ✅ Downloaded 6900 test images...
# ✅ Downloaded 7000 test images...
# ✅ Downloaded 7100 test images...
# ✅ Downloaded 7200 test images...
# ✅ Downloaded 7300 test images...
# ✅ Downloaded 7400 test images...
# ✅ Downloaded 7500 test images...
# ✅ Downloaded 7600 test images...
# ✅ Downloaded 7700 test images...
# ✅ Downloaded 7800 test images...
# ✅ Downloaded 7900 test images...
# ✅ Downloaded 8000 test images...
# ✅ Downloaded 8100 test images...
# ✅ Downloaded 8200 test images...
# ✅ Downloaded 8300 test images...
# ✅ Downloaded 8400 test images...
# ✅ Downloaded 8500 test images...
# ✅ Downloaded 8600 test images...
# ✅ Downloaded 8700 test images...
# ✅ Downloaded 8800 test images...
# ✅ Downloaded 8900 test images...
# ✅ Downloaded 9000 test images...
# ✅ Downloaded 9100 test images...
# ✅ Downloaded 9200 test images...
# ✅ Downloaded 9300 test images...
# ✅ Downloaded 9400 test images...
# ✅ Downloaded 9500 test images...
# ✅ Downloaded 9600 test images...
# ✅ Downloaded 9700 test images...
# ✅ Downloaded 9800 test images...
# ✅ Downloaded 9900 test images...
# ✅ Downloaded 10000 test images...
# ✅ Downloaded 10100 test images...
# ✅ Downloaded 10200 test images...
# ✅ Downloaded 10300 test images...
# ✅ Downloaded 10400 test images...
# ✅ Downloaded 10500 test images...
# ✅ Downloaded 10600 test images...
# ✅ Downloaded 10700 test images...
# ✅ Downloaded 10800 test images...
# ✅ Downloaded 10900 test images...
# ✅ Downloaded 11000 test images...
# ✅ Downloaded 11100 test images...
# ✅ Downloaded 11200 test images...
# ✅ Downloaded 11300 test images...
# ✅ Downloaded 11400 test images...
# ✅ Downloaded 11500 test images...
# ✅ Downloaded 11600 test images...
# ✅ Downloaded 11700 test images...
# ✅ Downloaded 11800 test images...
# ✅ Downloaded 11900 test images...
# ✅ Downloaded 12000 test images...
# ✅ Downloaded 12100 test images...
# ✅ Downloaded 12200 test images...
# ✅ Downloaded 12300 test images...
# ✅ Downloaded 12400 test images...
# ✅ Downloaded 12500 test images...
# ✅ Downloaded 12600 test images...
# ✅ Downloaded 12700 test images...
# ✅ Downloaded 12800 test images...
# ✅ Downloaded 12900 test images...
# ✅ Downloaded 13000 test images...
# ✅ Downloaded 13100 test images...
# ✅ Downloaded 13200 test images...
# ✅ Downloaded 13300 test images...
# ✅ Downloaded 13400 test images...
# ✅ Downloaded 13500 test images...
# ✅ Downloaded 13600 test images...
# ✅ Downloaded 13700 test images...
# ✅ Downloaded 13800 test images...
# ✅ Downloaded 13900 test images...
# ✅ Downloaded 14000 test images...
# ✅ Downloaded 14100 test images...
# ✅ Downloaded 14200 test images...
# ✅ Downloaded 14300 test images...
# ✅ Downloaded 14400 test images...
# ✅ Downloaded 14500 test images...
# ✅ Downloaded 14600 test images...
# ✅ Downloaded 14700 test images...
# ✅ Downloaded 14800 test images...
# ✅ Downloaded 14900 test images...
# ✅ Downloaded 15000 test images...
# ✅ Downloaded 15100 test images...
# ✅ Downloaded 15200 test images...
# ✅ Downloaded 15300 test images...
# ✅ Downloaded 15400 test images...
# ✅ Downloaded 15500 test images...
# ✅ Downloaded 15600 test images...
# ✅ Downloaded 15700 test images...
# ✅ Downloaded 15800 test images...
# ✅ Downloaded 15900 test images...
# ✅ Downloaded 16000 test images...
# ✅ Downloaded 16100 test images...
# ✅ Downloaded 16200 test images...
# ✅ Downloaded 16300 test images...
# ✅ Downloaded 16400 test images...
# ✅ Downloaded 16500 test images...
# ✅ Downloaded 16600 test images...
# ✅ Downloaded 16700 test images...
# ✅ Downloaded 16800 test images...
# ✅ Downloaded 16900 test images...
# ✅ Downloaded 17000 test images...
# ✅ Downloaded 17100 test images...
# ✅ Downloaded 17200 test images...
# ✅ Downloaded 17300 test images...
# ✅ Downloaded 17400 test images...
# ✅ Downloaded 17500 test images...
# ✅ Downloaded 17600 test images...
# ✅ Downloaded 17700 test images...
# ✅ Downloaded 17800 test images...
# ✅ Downloaded 17900 test images...
# ✅ Downloaded 18000 test images...
# ✅ Downloaded 18100 test images...
# ✅ Downloaded 18200 test images...
# ✅ Downloaded 18300 test images...
# ✅ Downloaded 18400 test images...
# ✅ Downloaded 18500 test images...
# ✅ Downloaded 18600 test images...
# ✅ Downloaded 18700 test images...
# ✅ Downloaded 18800 test images...
# ✅ Downloaded 18900 test images...
# ✅ Downloaded 19000 test images...
# ✅ Downloaded 19100 test images...
# ✅ Downloaded 19200 test images...
# ✅ Downloaded 19300 test images...
# ✅ Downloaded 19400 test images...
# ✅ Downloaded 19500 test images...
# ✅ Downloaded 19600 test images...
# ✅ Downloaded 19700 test images...
# ✅ Downloaded 19800 test images...
# ✅ Downloaded 19900 test images...
# ✅ Downloaded 20000 test images...
# ✅ Downloaded 20100 test images...
# ✅ Downloaded 20200 test images...
# ✅ Downloaded 20300 test images...
# ✅ Downloaded 20400 test images...
# ✅ Downloaded 20500 test images...
# ✅ Downloaded 20600 test images...
# ✅ Downloaded 20700 test images...
# ✅ Downloaded 20800 test images...
# ✅ Downloaded 20900 test images...
# ✅ Downloaded 21000 test images...
# ✅ Downloaded 21100 test images...
# ✅ Downloaded 21200 test images...
# ✅ Downloaded 21300 test images...
# ✅ Downloaded 21400 test images...
# ✅ Downloaded 21500 test images...
# ✅ Downloaded 21600 test images...
# ✅ Downloaded 21700 test images...
# ✅ Downloaded 21800 test images...
# ✅ Downloaded 21900 test images...
# ✅ Downloaded 22000 test images...
# ✅ Downloaded 22100 test images...
# ✅ Downloaded 22200 test images...
# ✅ Downloaded 22300 test images...
# ✅ Downloaded 22400 test images...
# ✅ Downloaded 22500 test images...
# ✅ Downloaded 22600 test images...
# ✅ Downloaded 22700 test images...
# ✅ Downloaded 22800 test images...
# ✅ Downloaded 22900 test images...
# ✅ Downloaded 23000 test images...
# ✅ Downloaded 23100 test images...
# ✅ Downloaded 23200 test images...
# ✅ Downloaded 23300 test images...
# ✅ Downloaded 23400 test images...
# ✅ Downloaded 23500 test images...
# ✅ Downloaded 23600 test images...
# ✅ Downloaded 23700 test images...
# ✅ Downloaded 23800 test images...
# ✅ Downloaded 23900 test images...
# ✅ Downloaded 24000 test images...
# ✅ Downloaded 24100 test images...
# ✅ Downloaded 24200 test images...
# ✅ Downloaded 24300 test images...
# ✅ Downloaded 24400 test images...
# ✅ Downloaded 24500 test images...
# ✅ Downloaded 24600 test images...
# ✅ Downloaded 24700 test images...
# ✅ Downloaded 24800 test images...
# ✅ Downloaded 24900 test images...
# ✅ Downloaded 25000 test images...
# ✅ Downloaded 25100 test images...
# ✅ Downloaded 25200 test images...
# ✅ Downloaded 25300 test images...
# ✅ Downloaded 25400 test images...
# ✅ Downloaded 25500 test images...
# ✅ Downloaded 25600 test images...
# ✅ Downloaded 25700 test images...
# ✅ Downloaded 25800 test images...
# ✅ Downloaded 25900 test images...
# ✅ Downloaded 26000 test images...
# ✅ Downloaded 26100 test images...
# ✅ Downloaded 26200 test images...
# ✅ Downloaded 26300 test images...
# ✅ Downloaded 26400 test images...
# ✅ Downloaded 26500 test images...
# ✅ Downloaded 26600 test images...
# ✅ Downloaded 26700 test images...
# ✅ Downloaded 26800 test images...
# ✅ Downloaded 26900 test images...
# ✅ Downloaded 27000 test images...
# ✅ Downloaded 27100 test images...
# ✅ Downloaded 27200 test images...
# ✅ Downloaded 27300 test images...
# ✅ Downloaded 27400 test images...
# ✅ Downloaded 27500 test images...
# ✅ Downloaded 27600 test images...
# ✅ Downloaded 27700 test images...
# ✅ Downloaded 27800 test images...
# ✅ Downloaded 27900 test images...
# ✅ Downloaded 28000 test images...
# ✅ Downloaded 28100 test images...
# ✅ Downloaded 28200 test images...
# ✅ Downloaded 28300 test images...
# ✅ Downloaded 28400 test images...
# ✅ Downloaded 28500 test images...
# ✅ Downloaded 28600 test images...
# ✅ Downloaded 28700 test images...
# ✅ Downloaded 28800 test images...
# ✅ Downloaded 28900 test images...
# ✅ Downloaded 29000 test images...
# ✅ Downloaded 29100 test images...
# ✅ Downloaded 29200 test images...
# ✅ Downloaded 29300 test images...
# ✅ Downloaded 29400 test images...
# ✅ Downloaded 29500 test images...
# ✅ Downloaded 29600 test images...
# ✅ Downloaded 29700 test images...
# ✅ Downloaded 29800 test images...
# ✅ Downloaded 29900 test images...
# ✅ Downloaded 30000 test images...
# ✅ Downloaded 30100 test images...
# ✅ Downloaded 30200 test images...
# ✅ Downloaded 30300 test images...
# ✅ Downloaded 30400 test images...
# ✅ Downloaded 30500 test images...
# ✅ Downloaded 30600 test images...
# ✅ Downloaded 30700 test images...
# ✅ Downloaded 30800 test images...
# ✅ Downloaded 30900 test images...
# ✅ Downloaded 31000 test images...
# ✅ Downloaded 31100 test images...
# ✅ Downloaded 31200 test images...
# ✅ Downloaded 31300 test images...
# ✅ Downloaded 31400 test images...
# ✅ Downloaded 31500 test images...
# ✅ Downloaded 31600 test images...
# ✅ Downloaded 31700 test images...
# ✅ Downloaded 31800 test images...
# ✅ Downloaded 31900 test images...
# ✅ Downloaded 32000 test images...
# ✅ Downloaded 32100 test images...
# ✅ Downloaded 32200 test images...
# ✅ Downloaded 32300 test images...
# ✅ Downloaded 32400 test images...
# ✅ Downloaded 32500 test images...
# ✅ Downloaded 32600 test images...
# ✅ Downloaded 32700 test images...
# ✅ Downloaded 32800 test images...
# ✅ Downloaded 32900 test images...
# ✅ Downloaded 33000 test images...
# ✅ Downloaded 33100 test images...
# ✅ Downloaded 33200 test images...
# ✅ Downloaded 33300 test images...
# ✅ Downloaded 33400 test images...
# ✅ Downloaded 33500 test images...
# ✅ Downloaded 33600 test images...
# ✅ Downloaded 33700 test images...
# ✅ Downloaded 33800 test images...
# ✅ Downloaded 33900 test images...
# ✅ Downloaded 34000 test images...
# ✅ Downloaded 34100 test images...
# ✅ Downloaded 34200 test images...
# ✅ Downloaded 34300 test images...
# ✅ Downloaded 34400 test images...
# ✅ Downloaded 34500 test images...
# ✅ Downloaded 34600 test images...
# ✅ Downloaded 34700 test images...
# ✅ Downloaded 34800 test images...
# ✅ Downloaded 34900 test images...
# ✅ Downloaded 35000 test images...
# ✅ Downloaded 35100 test images...
# ✅ Downloaded 35200 test images...
# ✅ Downloaded 35300 test images...
# ✅ Downloaded 35400 test images...
# ✅ Downloaded 35500 test images...
# ✅ Downloaded 35600 test images...
# ✅ Downloaded 35700 test images...
# ✅ Downloaded 35800 test images...
# ✅ Downloaded 35900 test images...
# ✅ Downloaded 36000 test images...
# ✅ Downloaded 36100 test images...
# ✅ Downloaded 36200 test images...
# ✅ Downloaded 36300 test images...
# ✅ Downloaded 36400 test images...
# ✅ Downloaded 36500 test images...
# ✅ Downloaded 36600 test images...
# ✅ Downloaded 36700 test images...
# ✅ Downloaded 36800 test images...
# ✅ Downloaded 36900 test images...
# ✅ Downloaded 37000 test images...
# ✅ Downloaded 37100 test images...
# ✅ Downloaded 37200 test images...
# ✅ Downloaded 37300 test images...
# ✅ Downloaded 37400 test images...
# ✅ Downloaded 37500 test images...
# ✅ Downloaded 37600 test images...
# ✅ Downloaded 37700 test images...
# ✅ Downloaded 37800 test images...
# ✅ Downloaded 37900 test images...
# ✅ Downloaded 38000 test images...
# ✅ Downloaded 38100 test images...
# ✅ Downloaded 38200 test images...
# ✅ Downloaded 38300 test images...
# ✅ Downloaded 38400 test images...
# ✅ Downloaded 38500 test images...
# ✅ Downloaded 38600 test images...
# ✅ Downloaded 38700 test images...
# ✅ Downloaded 38800 test images...
# ✅ Downloaded 38900 test images...
# ✅ Downloaded 39000 test images...
# ✅ Downloaded 39100 test images...
# ✅ Downloaded 39200 test images...
# ✅ Downloaded 39300 test images...
# ✅ Downloaded 39400 test images...
# ✅ Downloaded 39500 test images...
# ✅ Downloaded 39600 test images...
# ✅ Downloaded 39700 test images...
# ✅ Downloaded 39800 test images...
# ✅ Downloaded 39900 test images...
# ✅ Downloaded 40000 test images...
# ✅ Downloaded 40100 test images...
# ✅ Downloaded 40200 test images...
# ✅ Downloaded 40300 test images...
# ✅ Downloaded 40400 test images...
# ✅ Downloaded 40500 test images...
# ✅ Downloaded 40600 test images...
# ✅ Downloaded 40700 test images...
# ✅ Downloaded 40800 test images...
# ✅ Downloaded 40900 test images...
# ✅ Downloaded 41000 test images...
# ✅ Downloaded 41100 test images...
# ✅ Downloaded 41200 test images...
# ✅ Downloaded 41300 test images...
# ✅ Downloaded 41400 test images...
# ✅ Downloaded 41500 test images...
# ✅ Downloaded 41600 test images...
# ✅ Downloaded 41700 test images...
# ✅ Downloaded 41800 test images...
# ✅ Downloaded 41900 test images...
# ✅ Downloaded 42000 test images...
# ❌ Failed to download https://m.media-amazon.com/images/I/813CjSgHj0S.jpg → cannot identify image file <_io.BytesIO object at 0x00000235BB0B5CB0>
# ✅ Downloaded 42100 test images...
# ✅ Downloaded 42200 test images...
# ✅ Downloaded 42300 test images...
# ✅ Downloaded 42400 test images...
# ✅ Downloaded 42500 test images...
# ✅ Downloaded 42600 test images...
# ✅ Downloaded 42700 test images...
# ✅ Downloaded 42800 test images...
# ✅ Downloaded 42900 test images...
# ✅ Downloaded 43000 test images...
# ✅ Downloaded 43100 test images...
# ✅ Downloaded 43200 test images...
# ✅ Downloaded 43300 test images...
# ✅ Downloaded 43400 test images...
# ✅ Downloaded 43500 test images...
# ✅ Downloaded 43600 test images...
# ✅ Downloaded 43700 test images...
# ✅ Downloaded 43800 test images...
# ✅ Downloaded 43900 test images...
# ✅ Downloaded 44000 test images...
# ✅ Downloaded 44100 test images...
# ✅ Downloaded 44200 test images...
# ✅ Downloaded 44300 test images...
# ✅ Downloaded 44400 test images...
# ✅ Downloaded 44500 test images...
# ✅ Downloaded 44600 test images...
# ✅ Downloaded 44700 test images...
# ✅ Downloaded 44800 test images...
# ✅ Downloaded 44900 test images...
# ✅ Downloaded 45000 test images...
# ✅ Downloaded 45100 test images...
# ✅ Downloaded 45200 test images...
# ✅ Downloaded 45300 test images...
# ✅ Downloaded 45400 test images...
# ✅ Downloaded 45500 test images...
# ✅ Downloaded 45600 test images...
# ✅ Downloaded 45700 test images...
# ✅ Downloaded 45800 test images...
# ✅ Downloaded 45900 test images...
# ✅ Downloaded 46000 test images...
# ✅ Downloaded 46100 test images...
# ✅ Downloaded 46200 test images...
# ✅ Downloaded 46300 test images...
# ✅ Downloaded 46400 test images...
# ✅ Downloaded 46500 test images...
# ✅ Downloaded 46600 test images...
# ✅ Downloaded 46700 test images...
# ✅ Downloaded 46800 test images...
# ✅ Downloaded 46900 test images...
# ✅ Downloaded 47000 test images...
# ✅ Downloaded 47100 test images...
# ✅ Downloaded 47200 test images...
# ✅ Downloaded 47300 test images...
# ✅ Downloaded 47400 test images...
# ✅ Downloaded 47500 test images...
# ✅ Downloaded 47600 test images...
# ✅ Downloaded 47700 test images...
# ✅ Downloaded 47800 test images...
# ✅ Downloaded 47900 test images...
# ✅ Downloaded 48000 test images...
# ✅ Downloaded 48100 test images...
# ✅ Downloaded 48200 test images...
# ✅ Downloaded 48300 test images...
# ✅ Downloaded 48400 test images...
# ✅ Downloaded 48500 test images...
# ✅ Downloaded 48600 test images...
# ✅ Downloaded 48700 test images...
# ✅ Downloaded 48800 test images...
# ✅ Downloaded 48900 test images...
# ✅ Downloaded 49000 test images...
# ✅ Downloaded 49100 test images...
# ✅ Downloaded 49200 test images...
# ✅ Downloaded 49300 test images...
# ✅ Downloaded 49400 test images...
# ✅ Downloaded 49500 test images...
# ✅ Downloaded 49600 test images...
# ✅ Downloaded 49700 test images...
# ✅ Downloaded 49800 test images...
# ✅ Downloaded 49900 test images...
# ✅ Downloaded 50000 test images...
# ✅ Downloaded 50100 test images...
# ✅ Downloaded 50200 test images...
# ✅ Downloaded 50300 test images...
# ✅ Downloaded 50400 test images...
# ✅ Downloaded 50500 test images...
# ✅ Downloaded 50600 test images...
# ✅ Downloaded 50700 test images...
# ✅ Downloaded 50800 test images...
# ✅ Downloaded 50900 test images...
# ✅ Downloaded 51000 test images...
# ✅ Downloaded 51100 test images...
# ✅ Downloaded 51200 test images...
# ✅ Downloaded 51300 test images...
# ✅ Downloaded 51400 test images...
# ✅ Downloaded 51500 test images...
# ✅ Downloaded 51600 test images...
# ✅ Downloaded 51700 test images...
# ✅ Downloaded 51800 test images...
# ✅ Downloaded 51900 test images...
# ✅ Downloaded 52000 test images...
# ✅ Downloaded 52100 test images...
# ✅ Downloaded 52200 test images...
# ✅ Downloaded 52300 test images...
# ✅ Downloaded 52400 test images...
# ✅ Downloaded 52500 test images...
# ✅ Downloaded 52600 test images...
# ✅ Downloaded 52700 test images...
# ✅ Downloaded 52800 test images...
# ✅ Downloaded 52900 test images...
# ✅ Downloaded 53000 test images...
# ✅ Downloaded 53100 test images...
# ✅ Downloaded 53200 test images...
# ✅ Downloaded 53300 test images...
# ✅ Downloaded 53400 test images...
# ✅ Downloaded 53500 test images...
# ✅ Downloaded 53600 test images...
# ✅ Downloaded 53700 test images...
# ✅ Downloaded 53800 test images...
# ✅ Downloaded 53900 test images...
# ✅ Downloaded 54000 test images...
# ✅ Downloaded 54100 test images...
# ✅ Downloaded 54200 test images...
# ✅ Downloaded 54300 test images...
# ✅ Downloaded 54400 test images...
# ✅ Downloaded 54500 test images...
# ✅ Downloaded 54600 test images...
# ✅ Downloaded 54700 test images...
# ✅ Downloaded 54800 test images...
# ✅ Downloaded 54900 test images...
# ✅ Downloaded 55000 test images...
# ✅ Downloaded 55100 test images...
# ✅ Downloaded 55200 test images...
# ✅ Downloaded 55300 test images...
# ✅ Downloaded 55400 test images...
# ✅ Downloaded 55500 test images...
# ✅ Downloaded 55600 test images...
# ✅ Downloaded 55700 test images...
# ✅ Downloaded 55800 test images...
# ✅ Downloaded 55900 test images...
# ✅ Downloaded 56000 test images...
# ✅ Downloaded 56100 test images...
# ✅ Downloaded 56200 test images...
# ✅ Downloaded 56300 test images...
# ✅ Downloaded 56400 test images...
# ✅ Downloaded 56500 test images...
# ✅ Downloaded 56600 test images...
# ✅ Downloaded 56700 test images...
# ✅ Downloaded 56800 test images...
# ✅ Downloaded 56900 test images...
# ✅ Downloaded 57000 test images...
# ✅ Downloaded 57100 test images...
# ✅ Downloaded 57200 test images...
# ✅ Downloaded 57300 test images...
# ✅ Downloaded 57400 test images...
# ✅ Downloaded 57500 test images...
# ✅ Downloaded 57600 test images...
# ✅ Downloaded 57700 test images...
# ✅ Downloaded 57800 test images...
# ✅ Downloaded 57900 test images...
# ✅ Downloaded 58000 test images...
# ✅ Downloaded 58100 test images...
# ✅ Downloaded 58200 test images...
# ✅ Downloaded 58300 test images...
# ✅ Downloaded 58400 test images...
# ✅ Downloaded 58500 test images...
# ✅ Downloaded 58600 test images...
# ✅ Downloaded 58700 test images...
# ✅ Downloaded 58800 test images...
# ✅ Downloaded 58900 test images...
# ✅ Downloaded 59000 test images...
# ✅ Downloaded 59100 test images...
# ✅ Downloaded 59200 test images...
# ✅ Downloaded 59300 test images...
# ✅ Downloaded 59400 test images...
# ✅ Downloaded 59500 test images...
# ✅ Downloaded 59600 test images...
# ✅ Downloaded 59700 test images...
# ✅ Downloaded 59800 test images...
# ✅ Downloaded 59900 test images...
# ✅ Downloaded 60000 test images...
# ✅ Downloaded 60100 test images...
# ✅ Downloaded 60200 test images...
# ✅ Downloaded 60300 test images...
# ✅ Downloaded 60400 test images...
# ✅ Downloaded 60500 test images...
# ✅ Downloaded 60600 test images...
# ✅ Downloaded 60700 test images...
# ✅ Downloaded 60800 test images...
# ✅ Downloaded 60900 test images...
# ✅ Downloaded 61000 test images...
# ✅ Downloaded 61100 test images...
# ✅ Downloaded 61200 test images...
# ✅ Downloaded 61300 test images...
# ✅ Downloaded 61400 test images...
# ✅ Downloaded 61500 test images...
# ✅ Downloaded 61600 test images...
# ✅ Downloaded 61700 test images...
# ✅ Downloaded 61800 test images...
# ✅ Downloaded 61900 test images...
# ✅ Downloaded 62000 test images...
# ✅ Downloaded 62100 test images...
# ✅ Downloaded 62200 test images...
# ✅ Downloaded 62300 test images...
# ✅ Downloaded 62400 test images...
# ✅ Downloaded 62500 test images...
# ✅ Downloaded 62600 test images...
# ✅ Downloaded 62700 test images...
# ✅ Downloaded 62800 test images...
# ✅ Downloaded 62900 test images...
# ✅ Downloaded 63000 test images...
# ✅ Downloaded 63100 test images...
# ✅ Downloaded 63200 test images...
# ✅ Downloaded 63300 test images...
# ✅ Downloaded 63400 test images...
# ✅ Downloaded 63500 test images...
# ✅ Downloaded 63600 test images...
# ✅ Downloaded 63700 test images...
# ✅ Downloaded 63800 test images...
# ✅ Downloaded 63900 test images...
# ✅ Downloaded 64000 test images...
# ✅ Downloaded 64100 test images...
# ✅ Downloaded 64200 test images...
# ✅ Downloaded 64300 test images...
# ✅ Downloaded 64400 test images...
# ✅ Downloaded 64500 test images...
# ✅ Downloaded 64600 test images...
# ✅ Downloaded 64700 test images...
# ✅ Downloaded 64800 test images...
# ✅ Downloaded 64900 test images...
# ✅ Downloaded 65000 test images...
# ✅ Downloaded 65100 test images...
# ✅ Downloaded 65200 test images...
# ✅ Downloaded 65300 test images...
# ✅ Downloaded 65400 test images...
# ✅ Downloaded 65500 test images...
# ✅ Downloaded 65600 test images...
# ✅ Downloaded 65700 test images...
# ✅ Downloaded 65800 test images...
# ✅ Downloaded 65900 test images...
# ✅ Downloaded 66000 test images...
# ✅ Downloaded 66100 test images...
# ✅ Downloaded 66200 test images...
# ✅ Downloaded 66300 test images...
# ✅ Downloaded 66400 test images...
# ✅ Downloaded 66500 test images...
# ✅ Downloaded 66600 test images...
# ✅ Downloaded 66700 test images...
# ✅ Downloaded 66800 test images...
# ✅ Downloaded 66900 test images...
# ✅ Downloaded 67000 test images...
# ✅ Downloaded 67100 test images...
# ✅ Downloaded 67200 test images...
# ✅ Downloaded 67300 test images...
# ✅ Downloaded 67400 test images...
# ✅ Downloaded 67500 test images...
# ✅ Downloaded 67600 test images...
# ✅ Downloaded 67700 test images...
# ✅ Downloaded 67800 test images...
# ✅ Downloaded 67900 test images...
# ✅ Downloaded 68000 test images...
# ✅ Downloaded 68100 test images...
# ✅ Downloaded 68200 test images...
# ✅ Downloaded 68300 test images...
# ✅ Downloaded 68400 test images...
# ✅ Downloaded 68500 test images...
# ✅ Downloaded 68600 test images...
# ✅ Downloaded 68700 test images...
# ✅ Downloaded 68800 test images...
# ✅ Downloaded 68900 test images...
# ✅ Downloaded 69000 test images...
# ✅ Downloaded 69100 test images...
# ✅ Downloaded 69200 test images...
# ✅ Downloaded 69300 test images...
# ✅ Downloaded 69400 test images...
# ✅ Downloaded 69500 test images...
# ✅ Downloaded 69600 test images...
# ✅ Downloaded 69700 test images...
# ✅ Downloaded 69800 test images...
# ✅ Downloaded 69900 test images...
# ✅ Downloaded 70000 test images...
# ✅ Downloaded 70100 test images...
# ✅ Downloaded 70200 test images...
# ✅ Downloaded 70300 test images...
# ✅ Downloaded 70400 test images...
# ✅ Downloaded 70500 test images...
# ✅ Downloaded 70600 test images...
# ✅ Downloaded 70700 test images...
# ✅ Downloaded 70800 test images...
# ✅ Downloaded 70900 test images...
# ✅ Downloaded 71000 test images...
# ✅ Downloaded 71100 test images...
# ✅ Downloaded 71200 test images...
# ✅ Downloaded 71300 test images...
# ✅ Downloaded 71400 test images...
# ✅ Downloaded 71500 test images...
# ✅ Downloaded 71600 test images...
# ✅ Downloaded 71700 test images...
# ✅ Downloaded 71800 test images...
# ✅ Downloaded 71900 test images...
# ✅ Downloaded 72000 test images...
# ✅ Downloaded 72100 test images...
# ✅ Downloaded 72200 test images...
# ✅ Downloaded 72300 test images...
# ✅ Downloaded 72400 test images...
# ✅ Downloaded 72500 test images...
# ✅ Downloaded 72600 test images...
# ✅ Downloaded 72700 test images...
# ✅ Downloaded 72800 test images...
# ✅ Downloaded 72900 test images...
# ✅ Downloaded 73000 test images...
# ✅ Downloaded 73100 test images...
# ✅ Downloaded 73200 test images...
# ✅ Downloaded 73300 test images...
# ✅ Downloaded 73400 test images...
# ✅ Downloaded 73500 test images...
# ✅ Downloaded 73600 test images...
# ✅ Downloaded 73700 test images...
# ✅ Downloaded 73800 test images...
# ✅ Downloaded 73900 test images...
# ✅ Downloaded 74000 test images...
# ✅ Downloaded 74100 test images...
# ✅ Downloaded 74200 test images...
# ✅ Downloaded 74300 test images...
# ✅ Downloaded 74400 test images...
# ✅ Downloaded 74500 test images...
# ✅ Downloaded 74600 test images...
# ✅ Downloaded 74700 test images...
# ✅ Downloaded 74800 test images...
# ✅ Downloaded 74900 test images...

# %%
import torch
import torchvision.models as models
from torchvision import transforms

# Load MobileNetV2 (pretrained)
mobilenet = models.mobilenet_v2(pretrained=True)
mobilenet = torch.nn.Sequential(*list(mobilenet.children())[:-1])  # Remove classifier
mobilenet.eval()

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def get_mobilenet_features(img_path):
    try:
        img = Image.open(img_path).convert('RGB')
        img_t = transform(img).unsqueeze(0)  # Add batch dimension
        with torch.no_grad():
            features = mobilenet(img_t)
        return features.squeeze().numpy()  # Shape: (1280,)
    except Exception as e:
        print(f"⚠️ Error processing {img_path}: {e}")
        return np.zeros(1280)  # fallback

# Now extract features for all downloaded images
X_train_img = []
for idx, row in train_df.iterrows():
    img_path = f"train_images/{row['sample_id']}.jpg"
    feat = get_mobilenet_features(img_path)
    X_train_img.append(feat)
X_train_img = np.array(X_train_img)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['clean_text'] = train_df['catalog_content'].fillna('unknown').apply(clean_text)
test_df['clean_text'] = test_df['catalog_content'].fillna('unknown').apply(clean_text)

tfidf = TfidfVectorizer(max_features=5000, stop_words='english', ngram_range=(1,2))
X_train_text = tfidf.fit_transform(train_df['clean_text'])
X_test_text = tfidf.transform(test_df['clean_text'])

# %%
# Convert TF-IDF to dense (if memory allows)
X_train_text_dense = X_train_text.toarray()
X_test_text_dense = X_test_text.toarray()

# Reshape image features to be 2D for stacking
X_train_img_reshaped = X_train_img.reshape(X_train_img.shape[0], -1)
# Assuming X_test_img is also extracted and available
# If not, you'll need to extract features for test images similarly to how you did for train images
# For now, assuming X_test_img exists and reshaping it:
# X_test_img_reshaped = X_test_img.reshape(X_test_img.shape[0], -1)
# NOTE: If you haven't extracted X_test_img yet, you'll need to add that step before this cell.

# Combine with image features
# Ensure X_test_img is available before running this part
# For demonstration, I'll assume X_test_img is available and reshaped
# X_train_combined = np.hstack([X_train_text_dense, X_train_img_reshaped])
# X_test_combined = np.hstack([X_test_text_dense, X_test_img_reshaped])

# Temporarily using only text features for model training to fix the stacking issue first.
# You will need to uncomment the lines above and ensure X_test_img is generated
# before running the combined model.
X_train_combined = X_train_text_dense
X_test_combined = X_test_text_dense

# %%
import numpy as np

def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0  # avoid division by zero
    return np.mean(diff) * 100

# %%
from xgboost import XGBRegressor

model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    random_state=42,
    tree_method='hist'
)

model.fit(X_train_combined, train_df['price'])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_true = train_df['price']
y_pred = model.predict(X_train_combined)

smape_score = smape(y_true, y_pred)
print(f"SMAPE: {smape_score:.2f}%")
# Out:
# SMAPE: 61.36%

# %%
submission = pd.DataFrame({
    'sample_id': test_df['sample_id'],
    'price': y_pred
})
submission.to_csv('test_out.csv', index=False)

print("✅ Submission saved to test_out.csv")
# Out:
# ✅ Submission saved to test_out.csv
